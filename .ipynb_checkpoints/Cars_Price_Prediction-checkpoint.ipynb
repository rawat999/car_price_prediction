# %% [markdown]
# # Car Price Prediction

# %%
#importing necessary libraries
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Reading CSV file
car_df = pd.read_csv("cars_price.csv")

# %%
# Creating Copy
car_orig = car_df.copy()

# %%
# Looking at structure of the dataset
car_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40000 entries, 0 to 39999
# Data columns (total 13 columns):
# Unnamed: 0             40000 non-null int64
# make                   40000 non-null object
# model                  40000 non-null object
# priceUSD               40000 non-null int64
# year                   40000 non-null int64
# condition              40000 non-null object
# mileage(kilometers)    40000 non-null float64
# fuel_type              40000 non-null object
# volume(cm3)            39970 non-null float64
# color                  40000 non-null object
# transmission           40000 non-null object
# drive_unit             38655 non-null object
# segment                36245 non-null object
# dtypes: float64(2), int64(3), object(8)
# memory usage: 4.0+ MB

# %% [markdown]
# <b> Clearly here, we can see that there is some NULL values in volume, drive_units and segment variables. </b>

# %%
car_df.columns
# Out:
# Index(['Unnamed: 0', 'make', 'model', 'priceUSD', 'year', 'condition',
#        'mileage(kilometers)', 'fuel_type', 'volume(cm3)', 'color',
#        'transmission', 'drive_unit', 'segment'],
#       dtype='object')

# %% [markdown]
# #### Drop Unwanted column

# %%
car_df.drop(columns = ['Unnamed: 0'],inplace = True)

# %%
# Summarizing the dataset
pd.set_option('display.float_format',lambda x: '%.3f' % x) # converted to 3 decimal places of float value
car_df.describe()
# Out:
#         priceUSD      year  mileage(kilometers)  volume(cm3)
# count  40000.000 40000.000            40000.000    39970.000
# mean    7430.384  2003.486           243433.200     2103.202
# std     8338.242     8.115           316703.267      938.725
# min       95.000  1938.000                0.000      500.000
# 25%     2350.000  1998.000           137000.000     1600.000
# 50%     5350.000  2004.000           228000.000     1995.000
# 75%     9850.000  2010.000           308761.000     2300.000
# max   195000.000  2019.000          9999999.000    20000.000

# %%
# Removing Duplicate data
car_df.drop_duplicates(keep = 'first',inplace = True)

# %%
car_df.shape
# Out:
# (39951, 12)

# %% [markdown]
# <b> 49 Duplicates </b> are removed from the data.

# %% [markdown]
# ### Data Cleaning

# %%
# Check number of missing values in each feature
car_df.isnull().sum()
# Out:
# make                      0
# model                     0
# priceUSD                  0
# year                      0
# condition                 0
# mileage(kilometers)       0
# fuel_type                 0
# volume(cm3)              30
# color                     0
# transmission              0
# drive_unit             1344
# segment                3752
# dtype: int64

# %% [markdown]
# <li> Missing Values:
#     <ol> volume(cm3) : 30 </ol>
#     <ol> drive_unit : 1344 </ol>
#     <ol> segment : 3752 </ol>
# </li>

# %% [markdown]
# #### variable price

# %%
sns.distplot(car_df['priceUSD'])

# %%
car_df['priceUSD'].describe()
# Out:
# count    39951.000
# mean      7431.945
# std       8340.854
# min         95.000
# 25%       2350.000
# 50%       5350.000
# 75%       9850.000
# max     195000.000
# Name: priceUSD, dtype: float64

# %%
sns.boxplot(y=car_df['priceUSD'])

# %%
sum(car_df['priceUSD']>125000)
# Out:
# 8

# %%
sum(car_df['priceUSD']<100)
# Out:
# 1

# %% [markdown]
# NOTE: WORKING RANGE for price will be 100 to 125000.

# %% [markdown]
# #### Variable year

# %%
yearwise_count = car_df['year'].value_counts().sort_index()
yearwise_count.head()
# Out:
# 1938    1
# 1945    1
# 1949    1
# 1950    2
# 1951    1
# Name: year, dtype: int64

# %%
sum(car_df['year']<1950)
# Out:
# 3

# %%
sns.regplot(x = 'year',y = 'priceUSD',scatter = True, fit_reg = False, data = car_df,color='green')
plt.title("priceUSD vs year")
plt.show()

# %% [markdown]
# Here, We can clearly see that as the year increases, the car prices are also increases.

# %% [markdown]
# NOTE: WORKING RANGE for year will be 1950 to 2019

# %% [markdown]
# ##### variable mileage

# %%
mileage_count = car_df['mileage(kilometers)'].value_counts().sort_index()
mileage_count.tail(10)
# Out:
# 5000000.000     1
# 5300000.000     1
# 5555555.000     4
# 5689754.000     1
# 6000000.000     1
# 6666666.000     3
# 7000000.000     1
# 7777777.000     1
# 8888888.000     1
# 9999999.000    16
# Name: mileage(kilometers), dtype: int64

# %%
sns.boxplot(y=car_df['mileage(kilometers)'])

# %%
sum(car_df['mileage(kilometers)']>5500000)
# Out:
# 28

# %%
sns.regplot(x = 'mileage(kilometers)',y = 'priceUSD',scatter = True, fit_reg = False, data = car_df,color='red')
plt.title("priceUSD vs mileage")
plt.show()

# %% [markdown]
# NOTE: WORKING RANGE for mileage will be 0 to 5500000

# %% [markdown]
# #####  variable volume(cm3)

# %%
volume_count = car_df['volume(cm3)'].value_counts().sort_index()
volume_count.tail(15)
# Out:
# 6800.000      1
# 7000.000      1
# 7500.000      2
# 8000.000      2
# 9983.000      1
# 10000.000     1
# 12000.000     1
# 13000.000     3
# 14000.000     3
# 15000.000     2
# 16000.000     6
# 16902.000     1
# 18000.000     9
# 19000.000     9
# 20000.000    21
# Name: volume(cm3), dtype: int64

# %%
sns.boxplot(y=car_df['volume(cm3)'])
plt.show()

# %%
car_df['volume(cm3)'].describe()
# Out:
# count   39921.000
# mean     2103.278
# std       938.996
# min       500.000
# 25%      1600.000
# 50%      1995.000
# 75%      2300.000
# max     20000.000
# Name: volume(cm3), dtype: float64

# %%
sns.regplot(x = 'volume(cm3)',y = 'priceUSD',scatter = True, fit_reg = False, data = car_df,color='blue')
plt.title("priceUSD vs volume")
plt.show()

# %%
sum(car_df['volume(cm3)']>8000)
# Out:
# 57

# %% [markdown]
# NOTE: WORKING RANGE for volume will be 500 to 8000

# %% [markdown]
# #### Drop those records which are out of working range

# %%
car = car_df[ (car_df['priceUSD'] > 100) 
            & (car_df['priceUSD'] < 125000)
            & (car_df['year'] >1950) 
            & (car_df['mileage(kilometers)'] < 5500000)
            & (car_df['volume(cm3)'] < 8000) ]

# %%
car.shape
# Out:
# (39816, 12)

# %% [markdown]
# NOTE: <b>~135 records dropped </b> after removing outliers of numerical features.

# %% [markdown]
# ### Visualizing Parameters

# %% [markdown]
# #### PriceUSD

# %%
sns.distplot(car.priceUSD)
plt.show()

# %%
sns.boxplot(y = car.priceUSD)
plt.show()

# %% [markdown]
# ##### year

# %%
sns.distplot(car.year)
plt.show()

# %%
sns.boxplot(y = car.year)
plt.show()

# %% [markdown]
# #### mileage

# %%
sns.distplot(car['mileage(kilometers)'])
plt.show()

# %%
sns.boxplot(y = car['mileage(kilometers)'])
plt.show()

# %% [markdown]
# #### volume

# %%
sns.distplot(car['volume(cm3)'])
plt.show()

# %%
sns.boxplot(y = car['volume(cm3)'])
plt.show()

# %% [markdown]
# ### Visualizing parameters after narrowing in working range

# %%
# year vs priceUSD
sns.regplot(x = 'year', y = 'priceUSD',scatter = True, fit_reg = False, data = car)
plt.show()

# %% [markdown]
# NOTE: Here we can clearly see that newer car has higher price. As the year of cars increases, prices also increases.

# %%
# year vs mileage
sns.regplot(x = 'mileage(kilometers)',y = 'priceUSD', scatter = True, fit_reg = False,data = car)
plt.show()

# %% [markdown]
# NOTE: Here we can see that there is increase in mileage, decreasing in price of cars.

# %%
# volume vs priceUSD
sns.regplot(x = 'volume(cm3)', y = 'priceUSD',scatter = True, fit_reg = False,data = car)
plt.show()

# %% [markdown]
# Here is some positive relationship between volume as price of cars.

# %% [markdown]
# ### Categorical Variable

# %%
car.head()
# Out:
#          make    model  priceUSD  year     condition  mileage(kilometers)  \
# 0       honda   accord       565  1993  with mileage           960015.000
# 1        ford   fusion      5550  2008  with mileage           172000.000
# 2      nissan    teana      8300  2008  with mileage           223000.000
# 3  volkswagen      fox      3300  2005  with mileage           140000.000
# 4      nissan  primera      2450  2002   with damage           413000.000
#
#   fuel_type  volume(cm3)     color transmission         drive_unit segment
# 0    petrol     2000.000     black    mechanics  front-wheel drive       D
# 1    diesel     1400.000    silver    mechanics  front-wheel drive       M
# 2    petrol     2500.000    purple         auto  front-wheel drive       D
# 3    petrol     1200.000      blue    mechanics  front-wheel drive       A
# 4    diesel     2200.000  burgundy    mechanics  front-wheel drive       D

# %%
sns.countplot(x = 'make',data = car)

# %% [markdown]
# cars are distributed over many companies

# %%
sns.boxplot(x = 'make', y = 'priceUSD',data = car)
plt.show()

# %% [markdown]
# Note: from box plot, clearly we can see that there is affects. considered for modelling.

# %%
#variable model
sns.countplot(x = 'model',data = car)
plt.show()

# %%
sns.boxplot(x = 'model', y = 'priceUSD',data = car)
plt.show()

# %%
# variable condition
sns.countplot(x = 'condition',data = car)
plt.show()

# %%
car['condition'].value_counts()
# Out:
# with mileage    39162
# with damage       340
# for parts         314
# Name: condition, dtype: int64

# %%
sns.boxplot(x = 'condition', y = 'priceUSD',data = car)
plt.show()

# %%
# variable fuel type
sns.countplot(x = 'fuel_type',data = car)
plt.show()

# %%
sns.boxplot(x = 'fuel_type', y = 'priceUSD',data = car)
plt.show()

# %%
# variable color
sns.countplot(x = 'color',data = car)
plt.show()

# %%
sns.boxplot(x = 'color', y = 'priceUSD',data = car)
plt.show()

# %%
# variable transmission
sns.countplot(x = 'transmission',data = car)
plt.show()

# %%
sns.boxplot(x = 'transmission', y = 'priceUSD',data = car)
plt.show()

# %%
# drive unit
sns.countplot(x = 'drive_unit',data = car)
plt.show()

# %%
sns.boxplot(x = 'drive_unit', y = 'priceUSD',data = car)
plt.show()

# %%
# drive segment
sns.countplot(x = 'segment',data = car)
plt.show()

# %%
sns.boxplot(x = 'segment', y = 'priceUSD',data = car)
plt.show()

# %%
car_copy = car.copy()

# %% [markdown]
# ### Correlations

# %%
car_select1 = car.select_dtypes(exclude = [object])
car_select1.head()
# Out:
#    priceUSD  year  mileage(kilometers)  volume(cm3)
# 0       565  1993           960015.000     2000.000
# 1      5550  2008           172000.000     1400.000
# 2      8300  2008           223000.000     2500.000
# 3      3300  2005           140000.000     1200.000
# 4      2450  2002           413000.000     2200.000

# %%
car_select1.corr()
# Out:
#                      priceUSD   year  mileage(kilometers)  volume(cm3)
# priceUSD                1.000  0.632               -0.232        0.371
# year                    0.632  1.000               -0.300        0.053
# mileage(kilometers)    -0.232 -0.300                1.000        0.034
# volume(cm3)             0.371  0.053                0.034        1.000

# %%
car_select1.corr().loc[:,'priceUSD'].abs().sort_values(ascending = False)[1:]
# Out:
# year                  0.632
# volume(cm3)           0.371
# mileage(kilometers)   0.232
# Name: priceUSD, dtype: float64

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 39816 entries, 0 to 39999
# Data columns (total 12 columns):
# make                   39816 non-null object
# model                  39816 non-null object
# priceUSD               39816 non-null int64
# year                   39816 non-null int64
# condition              39816 non-null object
# mileage(kilometers)    39816 non-null float64
# fuel_type              39816 non-null object
# volume(cm3)            39816 non-null float64
# color                  39816 non-null object
# transmission           39816 non-null object
# drive_unit             38480 non-null object
# segment                36113 non-null object
# dtypes: float64(2), int64(2), object(8)
# memory usage: 5.2+ MB

# %% [markdown]
# ## Modelling

# %%
#Removing missing values
car_omit = car.dropna(axis = 0)
car_omit.shape
# Out:
# (34894, 12)

# %%
# converting categorical values in dummy variables
car_omit = pd.get_dummies(car_omit,drop_first = True)
car_omit.shape
# Out:
# (34894, 538)

# %%
# Importing some necessary libraries
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# %%
# separating input and output features
x1 = car_omit.drop(['priceUSD'],axis = 'columns',inplace = False)
y1 = car_omit['priceUSD']

# %%
# plotting the variable price
prices = pd.DataFrame({"1. Before": y1, "2. After": np.log(y1)})
prices.hist()
plt.show()

# %%
# Transforming price varible into log variale
y1 = np.log(y1)

# %%
# Split Train and Test Set
X_train, X_test, y_train, y_test = train_test_split(x1,y1,test_size = 0.3,random_state = 3)
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (24425, 537) (10469, 537) (24425,) (10469,)

# %% [markdown]
# ### Baseline Model for omitted data

# %% [markdown]
# we are making a base model by using test data mean value.
# This is set a benchmark and to compare it with our regression model.

# %%
# finding the mean for test data value
base_pred = np.mean(y_test)

# %%
# repeating same value till the test length
base_pred = np.repeat(base_pred,len(y_test))

# %%
# finding RMSE
base_root_mean_squared_error = np.sqrt(mean_squared_error(y_test,base_pred))
print(base_root_mean_squared_error)
# Out:
# 1.0324230363771656

# %%
base_pred
# Out:
# array([8.44494248, 8.44494248, 8.44494248, ..., 8.44494248, 8.44494248,
#        8.44494248])

# %%
y_test
# Out:
# 21070    7.090
# 11869    9.215
# 29823    9.554
# 5572     8.319
# 25799    9.024
# 37700    9.359
# 20287    9.099
# 24966    8.780
# 23036   10.968
# 27997    9.048
# 25535    9.480
# 12214    9.273
# 19786    9.060
# 2821     9.367
# 17873    9.240
# 15518    8.639
# 20733    8.613
# 16549    6.215
# 22732    8.854
# 10388    8.748
# 14601    7.116
# 25826    8.987
# 32329    7.696
# 24846    9.388
# 12984    8.132
# 39724    8.909
# 24206    7.650
# 17037    9.433
# 16488    8.294
# 31128    9.699
#          ...
# 8387     6.477
# 34304    8.613
# 23617    9.582
# 378      7.438
# 12043    8.189
# 24533    7.919
# 38736    5.704
# 11424    6.397
# 6367     8.146
# 21688    8.896
# 8347     6.215
# 16079   10.232
# 9740     6.397
# 33856    8.102
# 10314    6.685
# 33734    9.409
# 39674    6.802
# 16530    6.745
# 4943     7.650
# 9245     8.700
# 5582     9.099
# 28890    8.862
# 21454    8.517
# 1193     7.937
# 28992    8.175
# 3299     8.716
# 531      9.306
# ...

# %% [markdown]
# ### Linear regression with omitted data

# %%
# setting intercept as true
lgr = LinearRegression(fit_intercept = True)

# %%
# fit the model
model_lin1 = lgr.fit(X_train,y_train)

# %%
# predicting model on test data
car_predictions_lin1 = model_lin1.predict(X_test)

# %%
# computing MSE and RMSE
lin_mse1 = mean_squared_error(y_test,car_predictions_lin1)
lin_rmse1 = np.sqrt(lin_mse1)

# %%
print(lin_mse1,lin_rmse1)
# Out:
# 131998.79992470937 363.3163909386822

# %%
# R Squared Error
r2_lin_test1 = model_lin1.score(X_test,y_test)
r2_lin_train1 = model_lin1.score(X_train,y_train)
print(r2_lin_test1,r2_lin_train1)
# Out:
# -123837.1940733733 0.9175361574789127

# %%
# Residuals plot
residual1  = y_test - car_predictions_lin1
sns.regplot(x = car_predictions_lin1, y = residual1,scatter = True, fit_reg= False )
plt.show()

# %%
count = 0
for res in residual1:
    if res > 2 or res < -2:
        count +=1
        print(res)
        
print(count)
# Out:
# -2.0077289075358093
# 3623.4706768807105
# 2450.1049737349003
# 2.268877114835134
# -28024.48321499651
# 2450.5094209889303
# 2.118206229799485
# -2.1155373095280936
# -2.360918996177946
# 2.442594614622733
# 2.139202330822555
# -2.0612278437848337
# 2.1713423998566537
# 2.3353047964340696
# -1467.1311438794842
# -21592.264362719743
# -2.0361756438485354
# -9359.999360669586
# 3623.4688170984423
# -2.3819925407432434
# -1466.810643017026
# 2.257896342345017
# 340.96117544705186
# 2.9736162108179567
# 24
